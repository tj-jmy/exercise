# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not (os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(
    root='./mnist/', train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(
    dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)

test_data = torchvision.datasets.MNIST(root='./mnist/', train=False)
test_x = Variable(torch.unsqueeze(test_data.test_data, dim=1),
                  volatile=True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(  # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,
                out_channels=32,
                kernel_size=7,
                stride=1,
                padding="same",
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d((2, 2)),  # pooling operation function
        )
        self.conv2 = nn.Sequential(  # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(32, 64, 5, 1, "same"),
            nn.ReLU(),
            nn.MaxPool2d(2),


        )
        # full connection layer one
        self.out1 = nn.Linear(7*7*64, 1024, bias=True)

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024, 10, bias=True)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _, pre_index = torch.max(y_pre, 1)
    pre_index = pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x, y = Variable(x_), Variable(y_)
            output = cnn(x)
            loss = loss_func(output, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if step != 0 and step % 20 == 0:
                print("=" * 10, step, "="*5, "="*5,
                      "test accuracy is ", test(cnn), "=" * 10)


if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# C:\Users\80615\AppData\Local\Temp\ipykernel_19676\4273218602.py:26: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data, dim=1),
# C:\Users\80615\AppData\Local\Temp\ipykernel_19676\4273218602.py:71: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.266 ==========
# ========== 40 ===== ===== test accuracy is  0.354 ==========
# ========== 60 ===== ===== test accuracy is  0.486 ==========
# ========== 80 ===== ===== test accuracy is  0.564 ==========
# ========== 100 ===== ===== test accuracy is  0.614 ==========
# ========== 120 ===== ===== test accuracy is  0.668 ==========
# ========== 140 ===== ===== test accuracy is  0.68 ==========
# ========== 160 ===== ===== test accuracy is  0.714 ==========
# ========== 180 ===== ===== test accuracy is  0.742 ==========
# ========== 200 ===== ===== test accuracy is  0.762 ==========
# ========== 220 ===== ===== test accuracy is  0.778 ==========
# ========== 240 ===== ===== test accuracy is  0.83 ==========
# ========== 260 ===== ===== test accuracy is  0.826 ==========
# ========== 280 ===== ===== test accuracy is  0.828 ==========
# ========== 300 ===== ===== test accuracy is  0.852 ==========
# ========== 320 ===== ===== test accuracy is  0.86 ==========
# ========== 340 ===== ===== test accuracy is  0.876 ==========
# ========== 360 ===== ===== test accuracy is  0.892 ==========
# ========== 380 ===== ===== test accuracy is  0.87 ==========
# ========== 400 ===== ===== test accuracy is  0.896 ==========
# ========== 420 ===== ===== test accuracy is  0.906 ==========
# ========== 440 ===== ===== test accuracy is  0.896 ==========
# ========== 460 ===== ===== test accuracy is  0.896 ==========
# ========== 480 ===== ===== test accuracy is  0.906 ==========
# ========== 500 ===== ===== test accuracy is  0.918 ==========
# ========== 520 ===== ===== test accuracy is  0.922 ==========
# ========== 540 ===== ===== test accuracy is  0.906 ==========
# ========== 560 ===== ===== test accuracy is  0.92 ==========
# ========== 580 ===== ===== test accuracy is  0.928 ==========
# ========== 600 ===== ===== test accuracy is  0.912 ==========
# ========== 620 ===== ===== test accuracy is  0.936 ==========
# ========== 640 ===== ===== test accuracy is  0.932 ==========
# ========== 660 ===== ===== test accuracy is  0.938 ==========
# ========== 680 ===== ===== test accuracy is  0.93 ==========
# ========== 700 ===== ===== test accuracy is  0.926 ==========
# ========== 720 ===== ===== test accuracy is  0.936 ==========
# ========== 740 ===== ===== test accuracy is  0.938 ==========
# ========== 760 ===== ===== test accuracy is  0.934 ==========
# ========== 780 ===== ===== test accuracy is  0.934 ==========
# ========== 800 ===== ===== test accuracy is  0.934 ==========
# ========== 820 ===== ===== test accuracy is  0.944 ==========
# ========== 840 ===== ===== test accuracy is  0.928 ==========
# ========== 860 ===== ===== test accuracy is  0.936 ==========
# ========== 880 ===== ===== test accuracy is  0.938 ==========
# ========== 900 ===== ===== test accuracy is  0.942 ==========
# ========== 920 ===== ===== test accuracy is  0.938 ==========
# ========== 940 ===== ===== test accuracy is  0.936 ==========
# ========== 960 ===== ===== test accuracy is  0.936 ==========
# ========== 980 ===== ===== test accuracy is  0.958 ==========
# ========== 1000 ===== ===== test accuracy is  0.948 ==========
# ========== 1020 ===== ===== test accuracy is  0.954 ==========
# ========== 1040 ===== ===== test accuracy is  0.936 ==========
# ========== 1060 ===== ===== test accuracy is  0.94 ==========
# ========== 1080 ===== ===== test accuracy is  0.948 ==========
# ========== 1100 ===== ===== test accuracy is  0.948 ==========
# ========== 1120 ===== ===== test accuracy is  0.948 ==========
# ========== 1140 ===== ===== test accuracy is  0.94 ==========
# ========== 1160 ===== ===== test accuracy is  0.944 ==========
# ========== 1180 ===== ===== test accuracy is  0.948 ==========
# ========== 20 ===== ===== test accuracy is  0.944 ==========
# ========== 40 ===== ===== test accuracy is  0.954 ==========
# ========== 60 ===== ===== test accuracy is  0.958 ==========
# ========== 80 ===== ===== test accuracy is  0.952 ==========
# ========== 100 ===== ===== test accuracy is  0.95 ==========
# ========== 120 ===== ===== test accuracy is  0.95 ==========
# ========== 140 ===== ===== test accuracy is  0.944 ==========
# ========== 160 ===== ===== test accuracy is  0.956 ==========
# ========== 180 ===== ===== test accuracy is  0.946 ==========
# ========== 200 ===== ===== test accuracy is  0.946 ==========
# ========== 220 ===== ===== test accuracy is  0.962 ==========
# ========== 240 ===== ===== test accuracy is  0.956 ==========
# ========== 260 ===== ===== test accuracy is  0.96 ==========
# ========== 280 ===== ===== test accuracy is  0.962 ==========
# ========== 300 ===== ===== test accuracy is  0.956 ==========
# ========== 320 ===== ===== test accuracy is  0.952 ==========
# ========== 340 ===== ===== test accuracy is  0.956 ==========
# ========== 360 ===== ===== test accuracy is  0.958 ==========
# ========== 380 ===== ===== test accuracy is  0.95 ==========
# ========== 400 ===== ===== test accuracy is  0.972 ==========
# ========== 420 ===== ===== test accuracy is  0.964 ==========
# ========== 440 ===== ===== test accuracy is  0.958 ==========
# ========== 460 ===== ===== test accuracy is  0.962 ==========
# ========== 480 ===== ===== test accuracy is  0.948 ==========
# ========== 500 ===== ===== test accuracy is  0.96 ==========
# ========== 520 ===== ===== test accuracy is  0.95 ==========
# ========== 540 ===== ===== test accuracy is  0.956 ==========
# ========== 560 ===== ===== test accuracy is  0.962 ==========
# ========== 580 ===== ===== test accuracy is  0.968 ==========
# ========== 600 ===== ===== test accuracy is  0.958 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.972 ==========
# ========== 660 ===== ===== test accuracy is  0.976 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.976 ==========
# ========== 720 ===== ===== test accuracy is  0.966 ==========
# ========== 740 ===== ===== test accuracy is  0.96 ==========
# ========== 760 ===== ===== test accuracy is  0.972 ==========
# ========== 780 ===== ===== test accuracy is  0.96 ==========
# ========== 800 ===== ===== test accuracy is  0.966 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.966 ==========
# ========== 860 ===== ===== test accuracy is  0.968 ==========
# ========== 880 ===== ===== test accuracy is  0.964 ==========
# ========== 900 ===== ===== test accuracy is  0.968 ==========
# ========== 920 ===== ===== test accuracy is  0.966 ==========
# ========== 940 ===== ===== test accuracy is  0.964 ==========
# ========== 960 ===== ===== test accuracy is  0.968 ==========
# ========== 980 ===== ===== test accuracy is  0.964 ==========
# ========== 1000 ===== ===== test accuracy is  0.972 ==========
# ========== 1020 ===== ===== test accuracy is  0.964 ==========
# ========== 1040 ===== ===== test accuracy is  0.97 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.966 ==========
# ========== 1120 ===== ===== test accuracy is  0.966 ==========
# ========== 1140 ===== ===== test accuracy is  0.968 ==========
# ========== 1160 ===== ===== test accuracy is  0.97 ==========
# ========== 1180 ===== ===== test accuracy is  0.962 ==========
# ========== 20 ===== ===== test accuracy is  0.96 ==========
# ========== 40 ===== ===== test accuracy is  0.97 ==========
# ========== 60 ===== ===== test accuracy is  0.972 ==========
# ========== 80 ===== ===== test accuracy is  0.97 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.978 ==========
# ========== 140 ===== ===== test accuracy is  0.968 ==========
# ========== 160 ===== ===== test accuracy is  0.966 ==========
# ========== 180 ===== ===== test accuracy is  0.974 ==========
# ========== 200 ===== ===== test accuracy is  0.97 ==========
# ========== 220 ===== ===== test accuracy is  0.972 ==========
# ========== 240 ===== ===== test accuracy is  0.972 ==========
# ========== 260 ===== ===== test accuracy is  0.97 ==========
# ========== 280 ===== ===== test accuracy is  0.962 ==========
# ========== 300 ===== ===== test accuracy is  0.966 ==========
# ========== 320 ===== ===== test accuracy is  0.974 ==========
# ========== 340 ===== ===== test accuracy is  0.966 ==========
# ========== 360 ===== ===== test accuracy is  0.97 ==========
# ========== 380 ===== ===== test accuracy is  0.972 ==========
# ========== 400 ===== ===== test accuracy is  0.972 ==========
# ========== 420 ===== ===== test accuracy is  0.978 ==========
# ========== 440 ===== ===== test accuracy is  0.97 ==========
# ========== 460 ===== ===== test accuracy is  0.978 ==========
# ========== 480 ===== ===== test accuracy is  0.974 ==========
# ========== 500 ===== ===== test accuracy is  0.978 ==========
# ========== 520 ===== ===== test accuracy is  0.97 ==========
# ========== 540 ===== ===== test accuracy is  0.964 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.974 ==========
# ========== 600 ===== ===== test accuracy is  0.978 ==========
# ========== 620 ===== ===== test accuracy is  0.974 ==========
# ========== 640 ===== ===== test accuracy is  0.978 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.97 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.974 ==========
# ========== 740 ===== ===== test accuracy is  0.97 ==========
# ========== 760 ===== ===== test accuracy is  0.974 ==========
# ========== 780 ===== ===== test accuracy is  0.974 ==========
# ========== 800 ===== ===== test accuracy is  0.974 ==========
# ========== 820 ===== ===== test accuracy is  0.972 ==========
# ========== 840 ===== ===== test accuracy is  0.978 ==========
# ========== 860 ===== ===== test accuracy is  0.964 ==========
# ========== 880 ===== ===== test accuracy is  0.972 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.974 ==========
# ========== 940 ===== ===== test accuracy is  0.978 ==========
# ========== 960 ===== ===== test accuracy is  0.98 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.976 ==========
# ========== 1040 ===== ===== test accuracy is  0.978 ==========
# ========== 1060 ===== ===== test accuracy is  0.98 ==========
# ========== 1080 ===== ===== test accuracy is  0.976 ==========
# ========== 1100 ===== ===== test accuracy is  0.97 ==========
# ========== 1120 ===== ===== test accuracy is  0.976 ==========
# ========== 1140 ===== ===== test accuracy is  0.98 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.976 ==========
